# %%
import os
from pydub import AudioSegment

# %%
# !pip install pydub

# %%
for file in os.listdir('./TrainZindi'):
    x = file.split(".")
    print(x[0])
    print(file)
    sound = AudioSegment.from_mp3("./TrainZindi/"+ file)
    sound.export("./Train/" + x[0] + ".wav", format="wav")
# Out:
# 0009FW
# 0009FW.mp3
# 00M595
# 00M595.mp3
# 010FYT
# 010FYT.mp3
# 02E4IE
# 02E4IE.mp3
# 02WSAB
# 02WSAB.mp3
# 05BWUR
# 05BWUR.mp3
# 05EWY2
# 05EWY2.mp3
# 05XKMD
# 05XKMD.mp3
# 06A4LK
# 06A4LK.mp3
# 07PWPW
# 07PWPW.mp3
# 08BJVG
# 08BJVG.mp3
# 0BDIEF
# 0BDIEF.mp3
# 0BEEHQ
# 0BEEHQ.mp3
# 0C6ZAH
# 0C6ZAH.mp3
# 0CTGSV
# 0CTGSV.mp3
# 0DO1BS
# 0DO1BS.mp3
# 0E9DMQ
# 0E9DMQ.mp3
# 0EFEG5
# 0EFEG5.mp3
# 0FB4K5
# 0FB4K5.mp3
# 0FKB5F
# 0FKB5F.mp3
# 0GYN58
# 0GYN58.mp3
# 0IC96G
# 0IC96G.mp3
# 0JR3WB
# 0JR3WB.mp3
# 0JXHHP
# 0JXHHP.mp3
# 0LA6EP
# 0LA6EP.mp3
# 0LHCDU
# 0LHCDU.mp3
# 0LR0ZJ
# 0LR0ZJ.mp3
# 0LT5HO
# 0LT5HO.mp3
# 0MOSOT
# 0MOSOT.mp3
# 0NBCLO
# 0NBCLO.mp3
# 0NGDGE
# 0NGDGE.mp3
# 0NK3SQ
# 0NK3SQ.mp3
# 0NZG55
# 0NZG55.mp3
# 0REPAX
# 0REPAX.mp3
# 0RO00B
# 0RO00B.mp3
# 0S6VM2
# 0S6VM2.mp3
# 0TK0GY
# 0TK0GY.mp3
# 0V12SO
# 0V12SO.mp3
# 0V7BFX
# 0V7BFX.mp3
# 0W2ZMX
# 0W2ZMX.mp3
# 0WAYRY
# 0WAYRY.mp3
# 0WSTIM
# 0WSTIM.mp3
# 0WVHYD
# 0WVHYD.mp3
# 0X75SU
# 0X75SU.mp3
# 0ZY3RH
# 0ZY3RH.mp3
# 10JBLE
# ...
