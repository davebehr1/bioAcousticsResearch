# %%
import os

# %%
directory = "./Train"

files_in_directory = os.listdir(directory)

# %%
filtered_files = [file for file in files_in_directory if file.endswith(".png")]
filtered_files
# Out:
# []

# %%
for file in filtered_files:
    path_to_file = os.path.join(directory, file)
    os.remove(path_to_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-8e417862f3a6> in <module>()
#       1 for file in filtered_files:
#       2     path_to_file = os.path.join(directory, file)
# ----> 3     os.remove(path_to_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Train/G09YRE.png'

# %%
files_in_directory
# Out:
# ['G09YRE.png',
#  'FABY2X.mp3',
#  'VSYJGS.mp3',
#  'AKYJNB.png',
#  '3Q2FJL.mp3',
#  'FQ40KK.png',
#  '904ZIM.mp3',
#  'OLOQS1.mp3',
#  'KZ2TB9.mp3',
#  '6VWFS4.mp3',
#  'JEKIHU.mp3',
#  '2Q7ZAK.png',
#  'J1QZD9.png',
#  'LB6FSX.png',
#  '111CY1.mp3',
#  'B11XG9.png',
#  'G5OGSN.png',
#  'HIYOKT.png',
#  'TIZEKY.png',
#  'WR6NPI.png',
#  '7VYVZC.mp3',
#  'ETPCCT.mp3',
#  'TBO6IN.mp3',
#  'RQ8ISF.mp3',
#  '87BKSF.mp3',
#  'SYYP16.png',
#  '1UU889.mp3',
#  'HZBCJV.mp3',
#  'MQUJ6F.png',
#  'AYZV0P.mp3',
#  'EOOAHR.mp3',
#  'ZTPBR8.mp3',
#  'LGPIBG.png',
#  '3TT6BL.png',
#  'IRR7IX.png',
#  '5NPF5X.png',
#  'ISJEZP.png',
#  'QIV956.mp3',
#  'BEEYEM.png',
#  'L6X14Q.png',
#  'ZFHUXT.png',
#  'B6M8LI.mp3',
#  'X7JRYE.mp3',
#  'HBL1ZE.png',
#  'TWGPLN.png',
#  '2MAEP5.png',
#  'G6H69V.png',
#  'YGO2TK.mp3',
#  'C131YV.png',
#  'VF7WCM.mp3',
#  'U2BS2M.png',
#  'YAJFM5.mp3',
#  'XQRH9X.mp3',
#  '33NWCQ.mp3',
#  'Y0TNP2.mp3',
#  'KV3JWL.mp3',
#  'FRF50G.mp3',
#  'NMQW8C.png',
#  'LC54DI.mp3',
#  'I8LRZV.png',
#  'DMGGKY.mp3',
#  'ERUPRH.png',
#  '6U5700.png',
#  'RIS32Q.png',
#  '2MHPQN.mp3',
#  'EA8GM6.png',
#  'PZLZUE.mp3',
#  'G7L2RI.png',
#  'HCPP8T.png',
#  'B15C6B.mp3',
#  'K8CAZJ.png',
#  'HJ5STE.png',
#  'W5303P.png',
#  'PXG40D.mp3',
#  '7RK1TU.mp3',
#  'C7AKX8.png',
#  'AQ9UTN.mp3',
#  'DJXCA5.png',
#  '8FR31I.png',
#  'ATZ9YB.mp3',
#  '2LO3UF.png',
#  'RP71FC.png',
#  'IXR2H0.mp3',
#  'RV95LF.mp3',
#  'CIW7V5.mp3',
#  'SSUPZ8.png',
#  'P6KFPS.mp3',
#  'XIC1AI.png',
#  'G4A2JM.mp3',
#  'TPSNXQ.png',
#  'VUCAGQ.mp3',
#  'EID90A.png',
#  '2SASDP.mp3',
#  '98TIN2.mp3',
#  'ZE7FU1.png',
#  'EO00L4.png',
#  'L9HN88.png',
#  '4UOYRF.png',
#  'IFFBH8.mp3',
#  '27KSOO.png',
#  'TYCWFD.png',
#  'CT1P0N.mp3',
#  '0V12SO.mp3',
#  '3T66PS.mp3',
#  'YJT8HT.png',
#  '22T8PZ.mp3',
#  'XLO6HM.png',
#  '1F0K72.png',
#  '5KR18T.mp3',
#  'JY7EEZ.mp3',
#  'ZUROWD.png',
#  '5FAMR6.png',
#  '92MKTI.png',
#  'QVHZHS.mp3',
#  'O11BRT.mp3',
#  'C5K6VU.png',
#  'UU3WDD.png',
#  'G3MU3D.png',
#  'QJQL2P.mp3',
#  '6D7YJX.mp3',
#  'JDX016.mp3',
#  'YJE3B1.png',
#  '96G59P.mp3',
#  'TTYWDH.mp3',
#  '67DHHP.mp3',
#  '410ADL.mp3',
#  '6NDXCC.png',
#  'OR5E5I.png',
#  '647MAL.png',
#  'G8UPJO.png',
#  'BSXRFQ.png',
#  'E1VQ93.png',
#  'LIVB2J.mp3',
#  'MYMVRS.png',
#  'JDDIMP.mp3',
#  'PFU5N9.mp3',
#  'C87I6D.png',
#  'E7TGCS.png',
#  'YDIF0H.png',
#  'DR3BM7.png',
#  '7E0JKS.png',
#  '12UB63.mp3',
#  '9TUPQR.png',
#  'B31DP2.png',
#  'G770IS.mp3',
#  'Y9Z1DF.mp3',
#  'SZJ1EU.png',
#  '1WO820.png',
#  'P6ZLRA.png',
#  '4JOH8Q.png',
#  'R6QKFN.mp3',
#  'R5DGFW.png',
#  'DRIA96.mp3',
#  '707WSA.png',
#  '8CZAJL.png',
#  '50IP3W.png',
#  'C0P6SE.mp3',
#  '4ZAD8T.png',
#  '5OSWK7.png',
#  '2F73AH.mp3',
#  '0NGDGE.png',
#  'AC9A6J.mp3',
#  'MR1ABO.mp3',
#  'M7G6PS.mp3',
#  'RANBEJ.mp3',
#  'LZ648E.png',
#  'UGAHZQ.mp3',
#  'YVSHZ4.png',
#  '5I3KTW.mp3',
#  '4KB26N.mp3',
#  'QDAYDV.mp3',
#  'UMKQNI.png',
#  'MBEB56.mp3',
#  '2FUMON.png',
#  'W8KN1F.png',
#  '70ZL0Z.png',
#  'HHTYHS.mp3',
#  'FGJKAX.png',
#  'QUDYFZ.mp3',
#  'PEZXPM.mp3',
#  'LY2YQ1.mp3',
#  'GZXXPC.mp3',
#  'C73LGI.png',
#  'NOO3C1.png',
#  'U9MXLW.png',
#  '4LEPR7.png',
#  'UM4TL3.mp3',
#  'V72KH3.mp3',
#  'T403X8.png',
#  'OZO8P1.mp3',
#  '515QVN.mp3',
#  'DFVZ70.mp3',
#  '5LCE49.mp3',
#  'CYXSKB.png',
#  'KNKK4T.mp3',
#  'THC5QH.mp3',
#  'QA2PKW.mp3',
#  '27UITN.mp3',
#  'M8QWKJ.png',
#  '4BWGHT.mp3',
#  'FY2DQB.mp3',
#  'H2BV25.png',
#  'DFID0N.mp3',
#  '7S49D4.png',
#  'THDWS9.mp3',
#  '2SWP96.mp3',
#  'A8KUNQ.png',
#  'KD4BRT.png',
#  '78DD9P.mp3',
#  'XMYW63.png',
#  '9GBZDY.png',
#  '3GYUGB.png',
#  '3ZSLBK.png',
#  '31CWY2.mp3',
#  'ZVDQO4.png',
#  'TIFSSK.mp3',
#  '02WSAB.png',
#  'K78HZH.mp3',
#  'BQU23S.png',
#  'S3N4RD.png',
#  'I7BAS1.mp3',
#  'T9DAWS.png',
#  'CTXVOR.png',
#  '7WG76J.mp3',
#  'PM4J1K.mp3',
#  'UFISSH.mp3',
#  'T57XG9.png',
#  'JD7VEB.mp3',
#  'A7RI1O.png',
#  '0JXHHP.png',
#  '1KP787.png',
#  '0RO00B.mp3',
#  'KGI0ZB.mp3',
#  '4V0G4K.mp3',
#  '5BF1Y0.png',
#  'SCTFL4.mp3',
#  '2V6QGI.mp3',
#  'Z4CTLB.mp3',
#  '36Y5SR.png',
#  'KN6N64.mp3',
#  'IK5UZN.png',
#  'RLXTBN.mp3',
#  '1HKAJI.png',
#  'LDG69B.mp3',
#  '383WMM.png',
#  'RHUA16.png',
#  'UN1Q5P.mp3',
#  'ZKZX94.mp3',
#  'UTU9GZ.mp3',
#  'OTWHFG.png',
#  'BUP94Z.png',
#  'K3V3ET.mp3',
#  'YBNCPJ.mp3',
#  '98HFM7.mp3',
#  'XN28S7.png',
#  'ZUTL9N.mp3',
#  'WNARUZ.png',
#  '6JNEIG.mp3',
#  'Z80RFI.png',
#  'CQCKP4.png',
#  'I43RP3.png',
#  '6TM36Z.mp3',
#  'R4ZXC3.mp3',
#  'OKNDFW.png',
#  'PTU0LI.mp3',
#  'XG8W1J.png',
#  'FAIMBM.mp3',
#  '1F1KJ9.png',
#  '3C7TK0.mp3',
#  '0JR3WB.png',
#  'XONMIL.mp3',
#  '7QQZLF.png',
#  'X7MDHA.png',
#  'ZGQP9L.mp3',
#  'L6BSXS.mp3',
#  'KVRW7I.mp3',
#  '79Q1PG.mp3',
#  '6JLBA3.png',
#  '5R8OGO.png',
#  'IG0XEC.png',
#  '64WTIR.png',
#  'TMXFOW.mp3',
#  'VD8F6F.mp3',
#  'XQ27DS.png',
#  'BSN025.mp3',
#  'CALJ26.png',
#  '7GUY20.mp3',
#  'V3078O.mp3',
#  'DD1UQE.png',
#  'BGA0VI.mp3',
#  '0W2ZMX.mp3',
#  '2U3II0.png',
#  '528JW6.mp3',
#  'RVR7P4.mp3',
#  'ZPVK2Z.png',
#  'F64RUF.mp3',
#  'J2HC1Q.mp3',
#  'G3XWNM.png',
#  'IAZKCN.mp3',
#  'P9EUB6.mp3',
#  'BJQH7E.png',
#  'NE06FD.png',
#  'UZRLL5.mp3',
#  'IN1VXG.mp3',
#  'YTSMM4.mp3',
#  'I20B5U.mp3',
#  'D37M4C.mp3',
#  'HDHFZL.mp3',
#  '2NOEZQ.png',
#  'YP4S88.mp3',
#  '11E8KL.png',
#  '2BRXNQ.png',
#  'C02Q2L.mp3',
#  'BQM6SI.png',
#  'ROND4F.mp3',
#  'D6CFM2.png',
#  'L716AT.png',
#  'ZCOC3N.mp3',
#  'YO5UNN.png',
#  'YUMTHT.png',
#  'TRXLE7.png',
#  'ZKZXLC.png',
#  '161HVU.png',
#  'ILX5R5.png',
#  'KDB556.png',
#  'O46Z7A.mp3',
#  'GLGFFJ.png',
#  'UCGYIM.png',
#  'DB0Y0C.png',
#  '7GRLSS.png',
#  'MQ1YY3.mp3',
#  '5BFODF.mp3',
#  '1BRS5B.png',
#  '8OUOLH.mp3',
#  '425ZV1.mp3',
#  'WNZ0P7.mp3',
#  'F55P5F.mp3',
#  '69A8FF.mp3',
#  'WP0NHU.mp3',
#  '549SM5.png',
#  'XJOXOL.png',
#  'ORU7XC.mp3',
#  '0LR0ZJ.png',
#  'LAE7IM.mp3',
#  '6TUP24.mp3',
#  'TGTIYK.png',
#  '387C74.png',
#  'UA0VQX.png',
#  'MYMGDJ.mp3',
#  'IIGUEV.mp3',
#  'YHI28Y.mp3',
#  'HWU87A.mp3',
#  '4EPMY4.mp3',
#  'CEN5EN.png',
#  'J29VUY.png',
#  '2QU6PE.mp3',
#  '5PMO8C.mp3',
#  'DYM28T.png',
#  'LMII67.png',
#  'VUDGQZ.png',
#  'A2XVBS.mp3',
#  'CKO09M.png',
#  'Q1T5Y9.png',
#  'QH918P.mp3',
#  'FZ3698.png',
#  '8A56UR.mp3',
#  'ZJBT68.png',
#  '7DSTY1.mp3',
#  '6YHDNO.mp3',
#  'KBV096.mp3',
#  'MO93UW.png',
#  '4AQPQS.png',
#  'VXRDL7.mp3',
#  'PISVG6.png',
#  '10R8VS.mp3',
#  'FG4M7O.png',
#  'O9IM1F.png',
#  'JROPKR.png',
#  'UR13AQ.png',
#  'UIO0C9.mp3',
#  '0REPAX.png',
#  'S2IJX4.mp3',
#  'TFPRER.png',
#  '7AU981.png',
#  'UGPZ1L.mp3',
#  '9U04N3.mp3',
#  'VNZIQU.mp3',
#  'SW00KZ.mp3',
#  'WOMFDE.mp3',
#  'NRVI5U.mp3',
#  'Q0583O.mp3',
#  'UTRKUG.png',
#  '30C1TP.mp3',
#  'FSQ1MH.mp3',
#  'LZRHFD.mp3',
#  '16GR6O.png',
#  'I0GJDU.mp3',
#  'FUSNEK.mp3',
#  '9GDXYS.png',
#  'X9FQ9S.mp3',
#  '5KKV51.png',
#  '3Q2NSE.mp3',
#  '8FHZAX.mp3',
#  '9M50LS.png',
#  'XUWNAI.png',
#  '5150PI.mp3',
#  'BMSBGE.png',
#  'JYAX6E.mp3',
#  'W52D30.png',
#  'PBD9YP.png',
#  '3XT5GN.png',
#  'RJ3FIZ.png',
#  'LT28WK.mp3',
#  'PBV290.png',
#  '92UWH5.png',
#  '7EZO78.mp3',
#  '8BARZH.mp3',
#  '29ZC5S.png',
#  'P7DBB3.png',
#  '5T2C36.png',
#  'H61HPN.mp3',
#  'VY1EPX.png',
#  '2N1VZL.png',
#  'CWO9H9.mp3',
#  'QS8TDA.mp3',
#  '6JZD8D.mp3',
#  'A0QST3.mp3',
#  'UJ358Q.png',
#  '5FPP3F.png',
#  '9ELV4Z.mp3',
#  '3TRV3U.mp3',
#  '87AEY3.mp3',
#  'HH4ZKK.mp3',
#  '010FYT.png',
#  'V38EU6.png',
#  'ENKLG8.png',
#  '8X7I8U.mp3',
#  'CTCMFR.png',
#  'MSITDE.mp3',
#  'ZUQDUT.mp3',
#  '5FVPMV.mp3',
#  'M7TZQU.mp3',
#  'C9KZZX.mp3',
#  'F2SO1W.mp3',
#  'PC7KOU.mp3',
#  'UDV1OD.png',
#  '5D2WZM.mp3',
#  'TYJJEW.png',
#  '6WMPO4.mp3',
#  'ENA74W.png',
#  '7COG4O.mp3',
#  'WN1BJ4.png',
#  'BW3QIV.mp3',
#  'FN1UPL.png',
#  'NALBCZ.png',
#  'WQBCLK.png',
#  '4425U3.mp3',
#  '1BKDH1.png',
#  'BEF3A9.mp3',
#  'GC7MGZ.png',
#  'QFB1FR.png',
#  'XEAWBS.mp3',
#  'BU4QCD.png',
#  '38394O.png',
#  '3WKCKH.mp3',
#  'AB6APK.mp3',
#  'JRW37Q.png',
#  '4EVN55.png',
#  'SRQ7CG.mp3',
#  'FMVGU4.png',
#  '31BO6H.mp3',
#  '9WGDOR.mp3',
#  '8CVTGP.png',
#  '7DFEPK.mp3',
#  'GAYJBE.png',
#  'G39TKH.png',
#  '15P4UG.png',
#  '6EA6GI.png',
#  'TBNVLB.png',
#  'LLRQZ0.png',
#  'HHO61F.png',
#  'DC9XZF.png',
#  '8MBOCV.png',
#  'WOZFCI.mp3',
#  'HHJER7.png',
#  'Y2YEVD.mp3',
#  'YAZ7EN.png',
#  'ZZI6LM.png',
#  '6A4DTB.png',
#  'S19KYO.png',
#  'AP8F3H.png',
#  '5CR2D9.png',
#  'W7DO4D.mp3',
#  '7PXD0J.png',
#  'J90QMK.mp3',
#  'Q8MRZS.mp3',
#  'WDKN3Q.png',
#  '85ZHHL.mp3',
#  'MFJY1J.mp3',
#  'VGW5FF.mp3',
#  'MQ9G77.mp3',
#  'ZU6W1G.mp3',
#  'PAAJRR.png',
#  'ASHDZB.mp3',
#  'PBAJ7I.mp3',
#  '8S8KOQ.png',
#  'QU6R9V.png',
#  '8TYER7.png',
#  'DU38ZC.png',
#  'OIEIH3.mp3',
#  'ITMPIY.png',
#  'Z5I5W1.png',
#  '5YSFB4.png',
#  'YCDKTW.png',
#  '2G8ZBQ.mp3',
#  'YRM72L.png',
#  'E8K2FB.png',
#  'EA2P06.mp3',
#  'FPT48E.png',
#  'A2I8VH.png',
#  'Z4FPLO.mp3',
#  '7EO8QJ.png',
#  'S8DU85.mp3',
#  'UD9JUR.png',
#  'Y1NGYR.mp3',
#  'QTGN85.mp3',
#  'I9ZHHC.png',
#  '8AG8WR.mp3',
#  'VCOF0R.mp3',
#  '0NBCLO.png',
#  'ZLKD9S.mp3',
#  'DZ7UQ1.png',
#  'KD1GL6.mp3',
#  'R1GZMI.mp3',
#  'SPMSYM.mp3',
#  'TW7LD4.png',
#  'S26JDU.mp3',
#  'RHGZA4.png',
#  '17DT03.png',
#  'NUMHD7.mp3',
#  'QUGB99.mp3',
#  'O1YJGJ.mp3',
#  'YPN0XV.mp3',
#  'R8S6U2.mp3',
#  'JNCWZM.png',
#  'VN12XL.png',
#  '2XH9BD.mp3',
#  'SGZTDU.png',
#  'HG3ACC.mp3',
#  '74EQ14.mp3',
#  '5ERMTO.png',
#  'NBWT1M.mp3',
#  'M2KGD8.png',
#  'WQHRDN.png',
#  'WJT5UK.png',
#  '3QHTRI.png',
#  'O0EIHP.mp3',
#  'X423R5.mp3',
#  '89JB6J.png',
#  'K48R7H.png',
#  'Y8JKEV.mp3',
#  'II6QBK.mp3',
#  '05BWUR.png',
#  'T4TU74.mp3',
#  'G8RXGE.mp3',
#  '34BXW4.mp3',
#  '8CG8IQ.mp3',
#  'Y21AXM.mp3',
#  '2860FV.png',
#  '2CDMAU.png',
#  'J96TMY.mp3',
#  'RH4381.mp3',
#  '3UOM38.mp3',
#  'WOE4RX.png',
#  'QB5E6V.mp3',
#  '19S39R.mp3',
#  '90GB2C.mp3',
#  'RKYGLC.png',
#  'ZHKJOD.mp3',
#  'WREW4X.mp3',
#  'Y1QKZQ.png',
#  'K3UNAV.mp3',
#  'PGQDR4.png',
#  'LEFU84.png',
#  '4FOLNQ.mp3',
#  'OFVUH9.png',
#  'HQTVMS.png',
#  'MCYTA3.mp3',
#  'P8AQPO.png',
#  '2AHK1L.mp3',
#  'LD22ZD.png',
#  'MNTYVH.png',
#  'YE7OVK.png',
#  'TBY2HL.mp3',
#  'ZN6T1Y.mp3',
#  '1HAZVH.mp3',
#  'G3ZC09.png',
#  'YTL9I1.png',
#  '9M50UT.png',
#  'OY39QU.mp3',
#  '0GYN58.mp3',
#  'VNMYGG.png',
#  '8P0L15.mp3',
#  'ZGU3TG.mp3',
#  'C3CNEJ.png',
#  '3GNAEE.mp3',
#  '2POMSB.png',
#  'YK15FT.mp3',
#  'IUZHF7.mp3',
#  'AMND4O.png',
#  '26W9S5.mp3',
#  'O85VIP.mp3',
#  '82AZYT.png',
#  'TMAVX9.mp3',
#  'A9T9BZ.mp3',
#  'R92OB9.png',
#  'ZOUY5W.mp3',
#  '3ZDYSP.png',
#  'L2DGXF.mp3',
#  '8DEQS5.png',
#  'V9TDEI.png',
#  'NMU4A2.mp3',
#  'AQHT6S.mp3',
#  'ULOJF9.mp3',
#  '3XTNRY.png',
#  'HXFM2S.mp3',
#  '6FHMA2.png',
#  'L9OZP2.mp3',
#  'RKL6IU.mp3',
#  'L3EXE3.mp3',
#  'Y7595N.mp3',
#  'G5GPU6.png',
#  'SN9HWB.mp3',
#  'G71P6E.png',
#  'PM6EB0.png',
#  'C9FJWS.png',
#  'CQ1SCM.mp3',
#  'TFKD3L.mp3',
#  'B121SG.mp3',
#  'M7T6P6.png',
#  'R9L536.mp3',
#  '36AQ3J.png',
#  'D72QGN.mp3',
#  '0NZG55.png',
#  'FLTTTW.mp3',
#  'LKC31T.mp3',
#  'N6RJXH.mp3',
#  'WS6N2C.mp3',
#  'C49KXJ.png',
#  '2I6CGP.mp3',
#  'C619EL.png',
#  'PT13IX.png',
#  'VVOGMN.png',
#  '7D1BL4.png',
#  '7W6ENB.mp3',
#  'A8U9DJ.png',
#  '576SAI.png',
#  '3BNEI9.mp3',
#  'TEIYNE.png',
#  'OGD9L6.mp3',
#  'E3HI2T.png',
#  'WQLZZD.png',
#  '82IMPE.png',
#  'LFBA3R.mp3',
#  '2W5D8U.mp3',
#  'MPC7NS.mp3',
#  'WSJPYZ.mp3',
#  'TBTEY9.png',
#  'F41QWA.mp3',
#  '58D6LH.mp3',
#  '7ONQOA.mp3',
#  'Q67W0O.png',
#  'M4BA4O.png',
#  'CIE9PV.png',
#  '53GVWM.mp3',
#  'WNNHBZ.png',
#  'XC7M1A.mp3',
#  '24PE2T.mp3',
#  'WDSMMB.mp3',
#  'L158OW.mp3',
#  '88H2R0.png',
#  'ITXHI8.mp3',
#  'WLNX4N.mp3',
#  '4WRV02.png',
#  'J44SPZ.mp3',
#  'US784G.png',
#  'X5MDBI.mp3',
#  'QL5FWZ.png',
#  'H4HV0A.png',
#  'ZEK7LW.mp3',
#  '4Z7NKI.mp3',
#  'RRUD18.png',
#  'F64JK0.mp3',
#  'IERDX5.mp3',
#  'BUYD77.mp3',
#  '7TP77S.mp3',
#  'W978VR.png',
#  'P3FL9U.png',
#  'N3WLNU.mp3',
#  '14VDL7.mp3',
#  '833LKQ.mp3',
#  'ZLFC8O.mp3',
#  'EZISIN.mp3',
#  'B8BAOB.mp3',
#  '81H1M3.png',
#  '9JWTCV.png',
#  'BINKOZ.mp3',
#  'QFXVAH.mp3',
#  'O1MXLY.png',
#  '05EWY2.mp3',
#  'KFDAJT.png',
#  'W9LS0S.mp3',
#  'V1P8DM.png',
#  'RSBF5P.mp3',
#  'RSE7WI.png',
#  '08BJVG.png',
#  '83V8P7.png',
#  'RL9XUF.mp3',
#  'UVWAE9.png',
#  'DVA5NW.mp3',
#  'P88T65.mp3',
#  '8JNVDQ.mp3',
#  '2FZ21K.png',
#  '5QP8O1.mp3',
#  'JS6R16.mp3',
#  'O2PY5C.mp3',
#  'D9QUNT.mp3',
#  'I7JDIG.png',
#  'GDFZJZ.mp3',
#  '78XZA8.mp3',
#  '6OC5F8.png',
#  '5YLLWI.mp3',
#  'S2U2YB.mp3',
#  'MO6VXZ.png',
#  'R3DEWH.mp3',
#  'IUU1ZQ.mp3',
#  'PO9TV4.png',
#  'A1AEWC.mp3',
#  '2CY7QX.mp3',
#  '5B33ON.mp3',
#  '84H98H.png',
#  'PBOPHZ.png',
#  'NYOSKL.png',
#  '2VX6QZ.png',
#  'JPLU8E.png',
#  'VS2UUV.png',
#  'GH6FMQ.mp3',
#  'EZK6WR.png',
#  '7PUTEV.png',
#  'VVDDHA.mp3',
#  'O24I2W.png',
#  '1CNR4W.png',
#  'KFR54H.mp3',
#  'H823JO.png',
#  'V0X7SH.png',
#  'E8FYGU.png',
#  '8H11CX.mp3',
#  '9C1OLF.mp3',
#  'W0MJX8.mp3',
#  '0TK0GY.mp3',
#  '8FNFOD.mp3',
#  'Z3EN1Z.mp3',
#  'TZW2GN.mp3',
#  '9M4LNA.png',
#  'G3AYK7.png',
#  'U38PII.png',
#  'GVRZOH.mp3',
#  'ZXPU1Y.mp3',
#  'RQD7LL.png',
#  'IQBYEP.png',
#  'Q5939Z.mp3',
#  'GR3LF4.png',
#  'RDAQXP.png',
#  'HQDU7D.png',
#  'KEESB7.mp3',
#  'Q7A17U.mp3',
#  '2HQRAW.mp3',
#  'MFMG87.png',
#  '5DJMTH.png',
#  'VXMCE1.mp3',
#  '2EPIP6.png',
#  'TPL5CR.png',
#  'ZJ92A1.png',
#  'WYBPYH.mp3',
#  '1WY0H7.mp3',
#  'EVKAT2.mp3',
#  'BJONII.png',
#  '7WNUX9.png',
#  '1AMF0R.mp3',
#  'KZZ45A.png',
#  'CU5B1G.mp3',
#  'POG0BR.png',
#  'XPD9W9.png',
#  'MT04WN.png',
#  'FVA1KP.mp3',
#  '0V7BFX.png',
#  'X2OAA8.mp3',
#  'UASTJ2.mp3',
#  'XQD75G.png',
#  '2VOUQM.mp3',
#  '581PCQ.png',
#  'OXR50L.mp3',
#  'WA785Q.png',
#  '0E9DMQ.png',
#  '6CS96O.png',
#  'ZC3K2U.mp3',
#  'QO2TXW.png',
#  '25G89G.png',
#  'E7UQZ1.png',
#  'FZOCUG.mp3',
#  'MHQAYP.png',
#  'FKSYTD.png',
#  '54GX22.png',
#  'H5EIVW.png',
#  'PPFKVX.png',
#  'QPVWZR.mp3',
#  'K7GG87.png',
#  'JQEBYE.mp3',
#  'EBXT76.mp3',
#  'A3S6NC.png',
#  'WFYK5D.png',
#  'BTIAAW.mp3',
#  'QE1VCQ.png',
#  'ANXDI5.mp3',
#  '1JVURN.png',
#  '2S1DPZ.mp3',
#  'Y9JTSD.png',
#  '72IKIW.mp3',
#  '9AKHJU.mp3',
#  'JSMW8S.mp3',
#  '1593CS.png',
#  '2B5XR8.mp3',
#  'GO6G82.mp3',
#  'YQ6QLY.png',
#  'YRM5PD.mp3',
#  'QM5XH1.mp3',
#  'MPUR17.png',
#  'HG625P.mp3',
#  'CE0OZG.mp3',
#  '593X8Y.png',
#  '9O59UF.mp3',
#  'KNV1JI.png',
#  'A3U9UF.png',
#  '9OTOJM.png',
#  '7MBTNM.png',
#  'L8F7Z8.png',
#  '9Z7Y6A.mp3',
#  'NI18LC.mp3',
#  'VYCGG6.png',
#  '9L9BK2.mp3',
#  'OXSJME.mp3',
#  'D6XCCW.png',
#  'A0THVG.mp3',
#  'QQISOQ.png',
#  '4BJKI4.mp3',
#  'MCRPAJ.mp3',
#  'P9EKGO.mp3',
#  'MLJAI3.mp3',
#  'RZJZYF.png',
#  'QDOEZV.mp3',
#  'ZGB2OB.mp3',
#  'J6ZZ6E.png',
#  '4IR3EJ.png',
#  'JEPNDR.png',
#  'VNESTJ.png',
#  'IT41BD.png',
#  'LPYHOM.png',
#  'VTTM6X.png',
#  'SQVVA8.png',
#  'QX2W8F.mp3',
#  'K3ZQIA.mp3',
#  'W5XQKJ.mp3',
#  'U036O5.png',
#  'AK88S7.mp3',
#  'XQXKZD.png',
#  'D6R4EH.png',
#  '7IOSCQ.mp3',
#  'ZI8KWE.png',
#  '7HRULP.mp3',
#  'M1F74F.mp3',
#  'GC2R24.mp3',
#  'WLM14P.png',
#  '8N9UXP.png',
#  'KFYLAM.mp3',
#  'NYK3UV.mp3',
#  'I10JJ2.mp3',
#  '42292P.png',
#  '9TH80N.png',
#  'NGTTB8.png',
#  'BQVPOS.mp3',
#  '4KOMF8.png',
#  '8EBN0S.mp3',
#  'NZ174Z.mp3',
#  '5UZDMR.mp3',
#  '0NK3SQ.mp3',
#  '8EG6B7.mp3',
#  'V0BP6I.png',
#  'EFQIO3.png',
#  'C1ZABN.png',
#  'F52C94.mp3',
#  'SDR9V4.mp3',
#  '6E8F5S.png',
#  'K6XOZQ.png',
#  'FELU27.png',
#  'MFZPFM.png',
#  'PT1DS7.mp3',
#  '19TERJ.mp3',
#  'PFTSRD.png',
#  'MUVX9K.mp3',
#  'FALB14.mp3',
#  'JQAB2G.png',
#  'CQ8A0J.png',
#  'F7K6IJ.png',
#  'M14OIH.png',
#  'BO1CWQ.mp3',
#  'BZCE4Y.png',
#  'UNXY31.mp3',
#  'Z5PJ0U.png',
#  'PC13VV.mp3',
#  'N13BF0.mp3',
#  'RBDZ5A.png',
#  'N1AFG2.mp3',
#  '1PY6VH.mp3',
#  'Q8CV76.png',
#  '16W5CE.png',
#  'FRA6ZA.mp3',
#  'XIX5EM.png',
#  'OMH6N1.mp3',
#  'GU861X.mp3',
#  'C7HJ29.png',
#  'EPKHVC.png',
#  'G4IYG3.mp3',
#  'YP5IB9.png',
#  'YN28QN.png',
#  'DY9UXR.mp3',
#  'CU748X.png',
#  'JIQL6N.png',
#  'I1D36X.png',
#  '0BDIEF.png',
#  'EWIYDW.png',
#  '7KWR9L.png',
#  '7FPANY.mp3',
#  'Y81NYP.mp3',
#  '127GNR.png',
#  '6XIW3Q.png',
#  'VDUGPA.mp3',
#  'IS1H27.png',
#  '43N1JJ.mp3',
#  'RCKSO8.mp3',
#  'B55WJ9.png',
#  'OUFMWE.png',
#  'ZG0MYG.png',
#  'AEMO76.png',
#  '9MXTWH.mp3',
#  'OXP09C.mp3',
#  'JCKRVZ.mp3',
#  'FW5S9T.png',
#  '463JM4.png',
#  'MXQJ5S.mp3',
#  'X6CJBM.png',
#  '9MK7YJ.mp3',
#  'A4C2QS.mp3',
#  'EQIDHE.mp3',
#  'ZFABJS.png',
#  '9NSV7N.mp3',
#  'ISCUOU.png',
#  'PPXM8D.mp3',
#  '7VHHCK.mp3',
#  'RYAKAE.png',
#  '05XKMD.png',
#  'MXTLAA.mp3',
#  'CUQAQ3.png',
#  'LPX624.png',
#  '91R1IP.mp3',
#  'O5UHT2.mp3',
#  '1KZ4R5.mp3',
#  '40UFYC.png',
#  '5UPV0W.png',
#  '91T55Q.mp3',
#  'G7HLLB.mp3',
#  '8M0RFL.png',
#  'Q8F6DY.mp3',
#  'F6W0PC.mp3',
#  'ET4NWY.mp3',
#  'RGJNOE.png',
#  '48ELF5.mp3',
#  '9Y8V62.mp3',
#  'A2KSWI.mp3',
#  'N3Q03X.png',
#  'JPHQU2.mp3',
#  '9OTR52.png',
#  '6N53JN.png',
#  'AC5NT9.png',
#  'U4GNDS.mp3',
#  '0S6VM2.png',
#  'ZPQWIH.mp3',
#  'I4S80U.png',
#  'Z0PEIX.png',
#  '71DU1F.mp3',
#  'SL55WV.mp3',
#  ...]
